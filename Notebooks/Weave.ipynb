# %% [markdown]
# ```julia
# weave(source ;
#     doctype = :auto,
#     plotlib=:auto,
#     informat=:auto,
#     out_path=:doc,
#     args = Dict(),
#     fig_path = "figures",
#     fig_ext = nothing,
#     cache_path = "cache",
#     cache=:off,
#     template = nothing,
#     highlight_theme = nothing,
#     css = nothing,
#     latex_cmd = "pdflatex")
#
#
#      template = "custom.tpl"
# ```

# %%
using Weave
# Out:
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/abcsds/.julia/v0.6/IJulia/src/kernel.jl:31

# %%
weave(Pkg.dir("Weave","examples","gadfly_md_sample.jmd"),
    out_path = "../Reports",
  doctype = "md2html")
# Out:
# INFO: Weaving chunk 1 from line 21
# INFO: Weaving chunk 2 from line 45
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: sin{T <: Number}(x::AbstractArray{T}) is deprecated, use sin.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sin(::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at ./deprecated.jl:57
#  [3] capture_output(::Expr, ::Module, ::Bool, ::Bool, ::String, ::Bool) at /Users/abcsds/.julia/v0.6/Weave/src/run.jl:232
#  [4] run_code(::Weave.CodeChunk, ::Weave.Report, ::Module) at /Users/abcsds/.julia/v0.6/Weave/src/run.jl:204
#  [5] eval_chunk(::Weave.CodeChunk, ::Weave.Report, ::Module) at /Users/abcsds/.julia/v0.6/Weave/src/run.jl:292
#  [6] run_chunk(::Weave.CodeChunk, ::Weave.Report, ::Module) at /Users/abcsds/.julia/v0.6/Weave/src/run.jl:126
#  [7] #run#13(::String, ::Symbol, ::String, ::Dict{Any,Any}, ::String, ::Void, ::String, ::Symbol, ::Base.#run, ::Weave.WeaveDoc) at /Users/abcsds/.julia/v0.6/Weave/src/run.jl:90
#  [8] (::Base.#kw##run)(::Array{Any,1}, ::Base.#run, ::Weave.WeaveDoc) at ./<missing>:0
#  [9] #weave#4(::String, ::Symbol, ::Symbol, ::String, ::Dict{Any,Any}, ::String, ::Void, ::String, ::Symbol, ::Void, ::Void, ::Void, ::String, ::Weave.#weave, ::String) at /Users/abcsds/.julia/v0.6/Weave/src/Weave.jl:92
#  [10] (::Weave.#kw##weave)(::Array{Any,1}, ::Weave.#weave, ::String) at ./<missing>:0
#  [11] include_string(::String, ::String) at ./loading.jl:515
#  [12] include_string(::Module, ::String, ::String) at /Users/abcsds/.julia/v0.6/Compat/src/Compat.jl:407
#  [13] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/abcsds/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [14] eventloop(::ZMQ.Socket) at /Users/abcsds/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [15] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[2], in expression starting on line 1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[2]:1
# in render at /Users/abcsds/.julia/v0.6/Gadfly/src/geom/point.jl
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# INFO: Weaving chunk 3 from line 55
# INFO: Weaving chunk 4 from line 65
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:1
# INFO: Report weaved to ../Reports/gadfly_md_sample.html

# %%
weave("../templates/example.jmd", 
    out_path = "../Reports",
    plotlib = "Plots",
    template = "../templates/julia_html.tpl",
    args = Dict( "date" => Dates.format(now(), "dd/mm/yyyy HH:MM") ),
  doctype = "md2html")
# Out:
# INFO: Weaving chunk 1 from line 23
# INFO: Weaving chunk 2 from line 47
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[3]:1
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near In[3]:1
# in render at /Users/abcsds/.julia/v0.6/Gadfly/src/geom/point.jl
# INFO: Weaving chunk 3 from line 57
